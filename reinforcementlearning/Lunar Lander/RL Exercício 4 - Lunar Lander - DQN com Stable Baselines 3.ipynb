# %% [markdown]
# # RL - Exercício 4 - Lunar Lander (Stable Baselines 3)
#
# ### Stable Baselines 3 - Treinamento, armazenamento e carga do modelo
#
# Github Repo: [https://github.com/DLR-RM/stable-baselines3](https://github.com/DLR-RM/stable-baselines3)
#
# Documentation is available online: [https://stable-baselines3.readthedocs.io/](https://stable-baselines3.readthedocs.io/)
#
# ## Trabalho desenvolvido durante o MBA em Data Science / IA na FIAP - 2022~2023.
#
# ## Prof. Felipe Teodoro

# %% [markdown]
# ## Agente de Reinforcement Learning jogando Lunar Lander usando Deep Q-Learning

# %% [markdown]
# ## Instalação das dependências e do Stable Baselines usando PIP

# %%
# !apt-get install swig cmake
#!pip install setuptools==65.5.0

# !pip install box2d-py
# !pip install stable-baselines3[extra]

# !pip install imageio
# !pip install imageio_ffmpeg
# !pip install pyglet==1.5.1

# !apt update
# !apt install ffmpeg xvfb
# !pip install xvfbwrapper
# !pip install pyvirtualdisplay
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.1).
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 18 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (512 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 120875 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting box2d-py
#   Downloading box2d-py-2.3.8.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.5/374.5 kB 8.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.8-cp310-cp310-linux_x86_64.whl size=2349116 sha256=39176da6b4504b47aa9bff4bbc1699dee042c5724e160767cd6cccefe000e212
#   Stored in directory: /root/.cache/pip/wheels/47/01/d2/6a780da77ccb98b1d2facdd520a8d10838a03b590f6f8d50c0
# Successfully built box2d-py
# Installing collected packages: box2d-py
# Successfully installed box2d-py-2.3.8
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 4.3 MB/s eta 0:00:00
# Collecting gymnasium<0.30,>=0.28.1 (from stable-baselines3[extra])
#   Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 47.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.23.5)
# Requirement already satisfied: torch>=1.13 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.0.1+cu118)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.2.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (1.5.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.8.0.76)
# Requirement already satisfied: pygame in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.5.2)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (2.13.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (4.66.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (13.6.0)
# Collecting shimmy[atari]~=1.1.0 (from stable-baselines3[extra])
#   Downloading Shimmy-1.1.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (from stable-baselines3[extra]) (9.4.0)
# Collecting autorom[accept-rom-license]~=0.6.1 (from stable-baselines3[extra])
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (8.1.7)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.31.0)
# Collecting AutoROM.accept-rom-license (from autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra])
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 48.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra]) (4.5.0)
# Collecting farama-notifications>=0.0.1 (from gymnasium<0.30,>=0.28.1->stable-baselines3[extra])
#   Using cached Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting ale-py~=0.8.1 (from shimmy[atari]~=1.1.0->stable-baselines3[extra])
#   Downloading ale_py-0.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 67.5 MB/s eta 0:00:00
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.59.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.4.4)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.41.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.12.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.13->stable-baselines3[extra]) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->stable-baselines3[extra]) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.13->stable-baselines3[extra]) (17.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (4.43.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (23.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->stable-baselines3[extra]) (2023.3.post1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->stable-baselines3[extra]) (2.16.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.10/dist-packages (from ale-py~=0.8.1->shimmy[atari]~=1.1.0->stable-baselines3[extra]) (6.1.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->autorom[accept-rom-license]~=0.6.1->stable-baselines3[extra]) (2023.7.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]) (3.2.2)
# Building wheels for collected packages: AutoROM.accept-rom-license
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=f5f33147950784208641ddcdac66cc85e9942a8e590fe66430d3ac818e6b3b6a
#   Stored in directory: /root/.cache/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, gymnasium, ale-py, shimmy, AutoROM.accept-rom-license, autorom, stable-baselines3
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 farama-notifications-0.0.4 gymnasium-0.29.1 shimmy-1.1.0 stable-baselines3-2.1.0
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (2.31.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imageio) (1.23.5)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.10/dist-packages (from imageio) (9.4.0)
# Requirement already satisfied: imageio_ffmpeg in /usr/local/lib/python3.10/dist-packages (0.4.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from imageio_ffmpeg) (67.7.2)
# Collecting pyglet==1.5.1
#   Downloading pyglet-1.5.1-py2.py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 22.2 MB/s eta 0:00:00
# Installing collected packages: pyglet
# Successfully installed pyglet-1.5.1
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Hit:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Hit:6 https://ppa.launchpadcontent.net/c2d4u.team/c2d4u4.0+/ubuntu jammy InRelease
# Get:7 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,004 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Hit:9 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,269 kB]
# Get:11 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,081 kB]
# Hit:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:13 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,347 kB]
# Hit:14 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Fetched 5,043 kB in 3s (1,706 kB/s)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# 25 packages can be upgraded. Run 'apt list --upgradable' to see them.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# The following additional packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common
# The following NEW packages will be installed:
#   libfontenc1 libxfont2 libxkbfile1 x11-xkb-utils xfonts-base xfonts-encodings
#   xfonts-utils xserver-common xvfb
# 0 upgraded, 9 newly installed, 0 to remove and 25 not upgraded.
# Need to get 7,812 kB of archives.
# After this operation, 11.9 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-base all 1:1.0.5 [5,896 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.1 [28.0 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.1 [863 kB]
# Fetched 7,812 kB in 2s (3,706 kB/s)
# Selecting previously unselected package libfontenc1:amd64.
# (Reading database ... 121628 files and directories currently installed.)
# Preparing to unpack .../0-libfontenc1_1%3a1.1.4-1build3_amd64.deb ...
# Unpacking libfontenc1:amd64 (1:1.1.4-1build3) ...
# Selecting previously unselected package libxfont2:amd64.
# Preparing to unpack .../1-libxfont2_1%3a2.0.5-1build1_amd64.deb ...
# Unpacking libxfont2:amd64 (1:2.0.5-1build1) ...
# Selecting previously unselected package libxkbfile1:amd64.
# Preparing to unpack .../2-libxkbfile1_1%3a1.1.0-1build3_amd64.deb ...
# Unpacking libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Selecting previously unselected package x11-xkb-utils.
# Preparing to unpack .../3-x11-xkb-utils_7.7+5build4_amd64.deb ...
# Unpacking x11-xkb-utils (7.7+5build4) ...
# Selecting previously unselected package xfonts-encodings.
# Preparing to unpack .../4-xfonts-encodings_1%3a1.0.5-0ubuntu2_all.deb ...
# Unpacking xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Selecting previously unselected package xfonts-utils.
# Preparing to unpack .../5-xfonts-utils_1%3a7.7+6build2_amd64.deb ...
# Unpacking xfonts-utils (1:7.7+6build2) ...
# Selecting previously unselected package xfonts-base.
# Preparing to unpack .../6-xfonts-base_1%3a1.0.5_all.deb ...
# Unpacking xfonts-base (1:1.0.5) ...
# Selecting previously unselected package xserver-common.
# Preparing to unpack .../7-xserver-common_2%3a21.1.4-2ubuntu1.7~22.04.1_all.deb ...
# Unpacking xserver-common (2:21.1.4-2ubuntu1.7~22.04.1) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../8-xvfb_2%3a21.1.4-2ubuntu1.7~22.04.1_amd64.deb ...
# Unpacking xvfb (2:21.1.4-2ubuntu1.7~22.04.1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up xfonts-base (1:1.0.5) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.1) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.1) ...
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# Collecting xvfbwrapper
#   Downloading xvfbwrapper-0.2.9.tar.gz (5.6 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: xvfbwrapper
#   Building wheel for xvfbwrapper (setup.py) ... done
#   Created wheel for xvfbwrapper: filename=xvfbwrapper-0.2.9-py3-none-any.whl size=5009 sha256=f3ede899f278a9e444318106e35c9d5c655f2e59c8e0a65aaeb491464a7324f1
#   Stored in directory: /root/.cache/pip/wheels/cb/10/7d/2b7fdffccf837f7d5425931575fbee9caebe2c190931f9058b
# Successfully built xvfbwrapper
# Installing collected packages: xvfbwrapper
# Successfully installed xvfbwrapper-0.2.9
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Installing collected packages: pyvirtualdisplay
# Successfully installed pyvirtualdisplay-3.0

# %% [markdown]
# ## Desabilitar _warnings_

# %%
# Não sumiram todos os warnings, mas mantivemos por legibilidade
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ## Importar política, Agente de Reinforcement Learning, etc

# %%
import gymnasium as gym
import numpy as np

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback

from IPython import display
from IPython.display import HTML
#import pygame
from base64 import b64encode
import matplotlib.pyplot as plt
import imageio
from time import sleep
from tqdm import tqdm

import os
# Out:
# /usr/local/lib/python3.10/dist-packages/torch/utils/tensorboard/__init__.py:4: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if not hasattr(tensorboard, "__version__") or LooseVersion(

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Criação do ambiente Gym e instanciar o agente
#
# Para este exemplo, será usado o ambiente Lunar Lander do Gymnasium
#
# "Aterrissar fora da plataforma de pouso é possível. O combustível é infinito, então um agente pode aprender a voar e então pousar em sua primeira tentativa. Quatro ações distintas estão disponíveis: não fazer nada, disparar o motor de orientação à esquerda, disparar o motor principal (para baixo), disparar o motor de orientação à direita."
#
# Ambiente do módulo de pouso lunar: [https://gym.openai.com/envs/LunarLander-v2/](https://gym.openai.com/envs/LunarLander-v2/)
#
# ![Pouso Lunar](https://cdn-images-1.medium.com/max/960/1*f4VZPKOI0PYNWiwt0la0Rg.gif)
#
# Escolhemos MlpPolicy porque a entrada do Lunar Lander é um vetor, e não imagens.
#
# O tipo de ação a ser usada (discreta/contínua) será automaticamente deduzida do espaço de ação do ambiente.

# %%
env = gym.make("LunarLander-v2")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## Callback para salvar o modelo quando a recompensa média melhora
#
# Um monitor de recompensa acompanhará o treinamento, a cada 1024 passos, a média é calculada e se houver melhora em relação à última medição, o modelo atual será armazenado, substituindo o anterior.

# %%
class SaveOnBestRewardCallback(BaseCallback):
    def __init__(self, check_freq: int, model_dir: str, verbose=1):
        super(SaveOnBestRewardCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.model_dir = model_dir
        # atribui -inf para a média inicial
        self.best_mean_reward = -float("inf")
        self.episode_rewards = []

    def _on_step(self) -> bool:
        if self.num_timesteps % self.check_freq == 0:
            # Calcula a recompensa média dos últimos check_freq timesteps
            mean_reward = np.mean(self.episode_rewards[-self.check_freq:])
            print('mean_reward :', mean_reward)
            print('self.best_mean_reward:', self.best_mean_reward)

            # Verifica se a recompensa média melhorou
            if mean_reward > self.best_mean_reward:
                self.best_mean_reward = mean_reward

                # Salva o modelo com a nova melhor média
                print('SAVING MODEL IN', self.model_dir)
                self.model.save(os.path.join(self.model_dir, "best_model"))

        return True

    def _on_rollout_end(self) -> None:
        # Registra a recompensa do episódio
        if self.model.ep_info_buffer:
            last_episode_info = self.model.ep_info_buffer[-1]
            last_episode_reward = last_episode_info.get('r', 0)
            self.episode_rewards.append(last_episode_reward)

# Diretório para salvar os modelos (padrão colab)
model_dir = "/content/"

# Criar o callback
checkpoint_callback = SaveOnBestRewardCallback(check_freq=1024, model_dir = model_dir)

model = DQN(
    'MlpPolicy',
    env,
    verbose = 1,
    exploration_fraction = 0.1,
    exploration_final_eps = 0.02,
    learning_starts = 1000,
    target_update_interval = 1000,
    gradient_steps = 1,
    train_freq = (4, 'step'),
    batch_size = 32,
    learning_rate = 0.001,
    gamma = 0.99,
    seed = 42,
    policy_kwargs = {'net_arch': [64, 64]},
    tensorboard_log = model_dir
)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %% [markdown]
# ## Avaliação do Modelo Inicial

# %%
# Ambiente separado para avaliação
eval_env = gym.make('LunarLander-v2')

# Agente aleatório, antes do treinamento
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.10/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# mean_reward=-546.94 +/- 149.3965484381737

# %% [markdown]
# ## Treinamento do Agente

# %%
# Treinamento do agente
model.learn(total_timesteps=int(10e5), callback=checkpoint_callback)

# Não será salvo o modelo após o treinamento, porque
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
# mean_reward : 120.90370797265626
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 791      |
# |    ep_rew_mean      | 65.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1180     |
# |    fps              | 843      |
# |    time_elapsed     | 731      |
# |    total_timesteps  | 617378   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 3.2      |
# |    n_updates        | 154094   |
# ----------------------------------
# mean_reward : 159.96072388769534
# self.best_mean_reward: 243.19696613671877
# mean_reward : 102.61053874414064
# self.best_mean_reward: 243.19696613671877
# mean_reward : 51.82729515136719
# self.best_mean_reward: 243.19696613671877
# mean_reward : 86.92462164257813
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 813      |
# |    ep_rew_mean      | 59.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1184     |
# |    fps              | 843      |
# |    time_elapsed     | 735      |
# |    total_timesteps  | 620970   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.155    |
# |    n_updates        | 154992   |
# ----------------------------------
# mean_reward : 69.80516369824218
# self.best_mean_reward: 243.19696613671877
# mean_reward : 71.67694478125
# self.best_mean_reward: 243.19696613671877
# mean_reward : 68.28220476367187
# self.best_mean_reward: 243.19696613671877
# mean_reward : 11.202741084960937
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 831      |
# |    ep_rew_mean      | 51.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1188     |
# |    fps              | 843      |
# |    time_elapsed     | 740      |
# |    total_timesteps  | 624970   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.496    |
# |    n_updates        | 155992   |
# ----------------------------------
# mean_reward : -19.20980725292969
# self.best_mean_reward: 243.19696613671877
# mean_reward : -23.07295584277344
# self.best_mean_reward: 243.19696613671877
# mean_reward : -17.03519800976563
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 847      |
# |    ep_rew_mean      | 49.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1192     |
# |    fps              | 843      |
# |    time_elapsed     | 744      |
# |    total_timesteps  | 628209   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.145    |
# |    n_updates        | 156802   |
# ----------------------------------
# mean_reward : 39.77092275195311
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 836      |
# |    ep_rew_mean      | 60.3     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1196     |
# |    fps              | 843      |
# |    time_elapsed     | 746      |
# |    total_timesteps  | 629460   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.802    |
# |    n_updates        | 157114   |
# ----------------------------------
# mean_reward : 103.39731731054687
# self.best_mean_reward: 243.19696613671877
# mean_reward : 155.22163833398434
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 816      |
# |    ep_rew_mean      | 69.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1200     |
# |    fps              | 843      |
# |    time_elapsed     | 748      |
# |    total_timesteps  | 631447   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.182    |
# |    n_updates        | 157611   |
# ----------------------------------
# mean_reward : 213.66739375292966
# self.best_mean_reward: 243.19696613671877
# mean_reward : 216.52149588574218
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 817      |
# |    ep_rew_mean      | 64.7     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1204     |
# |    fps              | 843      |
# |    time_elapsed     | 751      |
# |    total_timesteps  | 633273   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.69     |
# |    n_updates        | 158068   |
# ----------------------------------
# mean_reward : 198.5081832314453
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 787      |
# |    ep_rew_mean      | 70.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1208     |
# |    fps              | 843      |
# |    time_elapsed     | 752      |
# |    total_timesteps  | 634271   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.142    |
# |    n_updates        | 158317   |
# ----------------------------------
# mean_reward : 171.21870093359377
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 755      |
# |    ep_rew_mean      | 72.8     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1212     |
# |    fps              | 843      |
# |    time_elapsed     | 753      |
# |    total_timesteps  | 635048   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.154    |
# |    n_updates        | 158511   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 730      |
# |    ep_rew_mean      | 78.4     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1216     |
# |    fps              | 842      |
# |    time_elapsed     | 754      |
# |    total_timesteps  | 635783   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.191    |
# |    n_updates        | 158695   |
# ----------------------------------
# mean_reward : 143.7725026621094
# self.best_mean_reward: 243.19696613671877
# mean_reward : 151.67081049414065
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 726      |
# |    ep_rew_mean      | 82.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1220     |
# |    fps              | 842      |
# |    time_elapsed     | 756      |
# |    total_timesteps  | 637814   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.313    |
# |    n_updates        | 159203   |
# ----------------------------------
# mean_reward : 161.65549773437505
# self.best_mean_reward: 243.19696613671877
# mean_reward : 174.10003463183597
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 706      |
# |    ep_rew_mean      | 87.5     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1224     |
# |    fps              | 842      |
# |    time_elapsed     | 758      |
# |    total_timesteps  | 639080   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.468    |
# |    n_updates        | 159519   |
# ----------------------------------
# mean_reward : 208.0970798232422
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 677      |
# |    ep_rew_mean      | 94.9     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1228     |
# |    fps              | 842      |
# |    time_elapsed     | 759      |
# |    total_timesteps  | 640131   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.27     |
# |    n_updates        | 159782   |
# ----------------------------------
# mean_reward : 178.03248376464848
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 657      |
# |    ep_rew_mean      | 98.2     |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1232     |
# |    fps              | 842      |
# |    time_elapsed     | 761      |
# |    total_timesteps  | 641221   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.26     |
# |    n_updates        | 160055   |
# ----------------------------------
# mean_reward : 193.25363588378906
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 632      |
# |    ep_rew_mean      | 106      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1236     |
# |    fps              | 842      |
# |    time_elapsed     | 762      |
# |    total_timesteps  | 642134   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.205    |
# |    n_updates        | 160283   |
# ----------------------------------
# mean_reward : 211.7467584033203
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 614      |
# |    ep_rew_mean      | 107      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1240     |
# |    fps              | 842      |
# |    time_elapsed     | 763      |
# |    total_timesteps  | 643155   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.168    |
# |    n_updates        | 160538   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 582      |
# |    ep_rew_mean      | 114      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1244     |
# |    fps              | 842      |
# |    time_elapsed     | 764      |
# |    total_timesteps  | 643880   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.963    |
# |    n_updates        | 160719   |
# ----------------------------------
# mean_reward : 186.1334533408203
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 561      |
# |    ep_rew_mean      | 118      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1248     |
# |    fps              | 842      |
# |    time_elapsed     | 765      |
# |    total_timesteps  | 644907   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.206    |
# |    n_updates        | 160976   |
# ----------------------------------
# mean_reward : 212.1466302783203
# self.best_mean_reward: 243.19696613671877
# mean_reward : 131.6349793808594
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 541      |
# |    ep_rew_mean      | 116      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1252     |
# |    fps              | 842      |
# |    time_elapsed     | 767      |
# |    total_timesteps  | 646242   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.195    |
# |    n_updates        | 161310   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 518      |
# |    ep_rew_mean      | 125      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1256     |
# |    fps              | 842      |
# |    time_elapsed     | 768      |
# |    total_timesteps  | 647115   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.125    |
# |    n_updates        | 161528   |
# ----------------------------------
# mean_reward : 105.56349039453126
# self.best_mean_reward: 243.19696613671877
# mean_reward : 116.4467162421875
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 489      |
# |    ep_rew_mean      | 133      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1260     |
# |    fps              | 842      |
# |    time_elapsed     | 769      |
# |    total_timesteps  | 648250   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.113    |
# |    n_updates        | 161812   |
# ----------------------------------
# mean_reward : 124.96401383496092
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | 140      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1264     |
# |    fps              | 842      |
# |    time_elapsed     | 771      |
# |    total_timesteps  | 649465   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.453    |
# |    n_updates        | 162116   |
# ----------------------------------
# mean_reward : 174.27663582128906
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 441      |
# |    ep_rew_mean      | 146      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1268     |
# |    fps              | 842      |
# |    time_elapsed     | 772      |
# |    total_timesteps  | 650647   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.325    |
# |    n_updates        | 162411   |
# ----------------------------------
# mean_reward : 213.26845210839844
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 412      |
# |    ep_rew_mean      | 157      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1272     |
# |    fps              | 842      |
# |    time_elapsed     | 774      |
# |    total_timesteps  | 651756   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.258    |
# |    n_updates        | 162688   |
# ----------------------------------
# mean_reward : 227.9155541982422
# self.best_mean_reward: 243.19696613671877
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 390      |
# |    ep_rew_mean      | 163      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1276     |
# |    fps              | 841      |
# |    time_elapsed     | 775      |
# |    total_timesteps  | 652789   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.377    |
# |    n_updates        | 162947   |
# ----------------------------------
# mean_reward : 226.45852091601563
# self.best_mean_reward: 243.19696613671877
# mean_reward : 256.9771561181641
# self.best_mean_reward: 243.19696613671877
# SAVING MODEL IN /content/
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 370      |
# |    ep_rew_mean      | 169      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1280     |
# |    fps              | 841      |
# |    time_elapsed     | 777      |
# |    total_timesteps  | 654398   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.585    |
# |    n_updates        | 163349   |
# ----------------------------------
# mean_reward : 233.13135299804685
# self.best_mean_reward: 256.9771561181641
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 346      |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1284     |
# |    fps              | 841      |
# |    time_elapsed     | 778      |
# |    total_timesteps  | 655586   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.187    |
# |    n_updates        | 163646   |
# ----------------------------------
# mean_reward : 225.8352880234375
# self.best_mean_reward: 256.9771561181641
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 315      |
# |    ep_rew_mean      | 182      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1288     |
# |    fps              | 841      |
# |    time_elapsed     | 779      |
# |    total_timesteps  | 656433   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.072    |
# |    n_updates        | 163858   |
# ----------------------------------
# mean_reward : 226.9415952763672
# self.best_mean_reward: 256.9771561181641
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1292     |
# |    fps              | 841      |
# |    time_elapsed     | 781      |
# |    total_timesteps  | 657463   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.574    |
# |    n_updates        | 164115   |
# ----------------------------------
# mean_reward : 221.7127022900391
# self.best_mean_reward: 256.9771561181641
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 294      |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1296     |
# |    fps              | 841      |
# |    time_elapsed     | 782      |
# |    total_timesteps  | 658881   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.23     |
# |    n_updates        | 164470   |
# ----------------------------------
# mean_reward : 243.35536721484374
# self.best_mean_reward: 256.9771561181641
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 284      |
# |    ep_rew_mean      | 189      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1300     |
# |    fps              | 841      |
# |    time_elapsed     | 784      |
# |    total_timesteps  | 659847   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.325    |
# |    n_updates        | 164711   |
# ----------------------------------
# mean_reward : 256.8363498154297
# self.best_mean_reward: 256.9771561181641
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 277      |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1304     |
# |    fps              | 841      |
# |    time_elapsed     | 785      |
# |    total_timesteps  | 661017   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.72     |
# |    n_updates        | 165004   |
# ----------------------------------
# mean_reward : 211.50200759375
# self.best_mean_reward: 256.9771561181641
# mean_reward : 218.15550634765623
# self.best_mean_reward: 256.9771561181641
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 284      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1308     |
# |    fps              | 841      |
# |    time_elapsed     | 787      |
# |    total_timesteps  | 662694   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.22     |
# |    n_updates        | 165423   |
# ----------------------------------
# mean_reward : 224.3720871689453
# self.best_mean_reward: 256.9771561181641
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 287      |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1312     |
# |    fps              | 841      |
# |    time_elapsed     | 788      |
# |    total_timesteps  | 663764   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.323    |
# |    n_updates        | 165690   |
# ----------------------------------
# mean_reward : 216.4255499755859
# self.best_mean_reward: 256.9771561181641
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1316     |
# |    fps              | 841      |
# |    time_elapsed     | 790      |
# |    total_timesteps  | 665018   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.173    |
# |    n_updates        | 166004   |
# ----------------------------------
# mean_reward : 260.6743967041016
# self.best_mean_reward: 256.9771561181641
# SAVING MODEL IN /content/
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 283      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1320     |
# |    fps              | 841      |
# |    time_elapsed     | 791      |
# |    total_timesteps  | 666085   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.296    |
# |    n_updates        | 166271   |
# ----------------------------------
# mean_reward : 238.34267711816403
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 281      |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1324     |
# |    fps              | 841      |
# |    time_elapsed     | 793      |
# |    total_timesteps  | 667215   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.281    |
# |    n_updates        | 166553   |
# ----------------------------------
# mean_reward : 239.41523847558594
# self.best_mean_reward: 260.6743967041016
# mean_reward : 231.42035580078124
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 286      |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1328     |
# |    fps              | 841      |
# |    time_elapsed     | 795      |
# |    total_timesteps  | 668760   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.255    |
# |    n_updates        | 166939   |
# ----------------------------------
# mean_reward : 216.6286993544922
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 285      |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1332     |
# |    fps              | 841      |
# |    time_elapsed     | 796      |
# |    total_timesteps  | 669765   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.344    |
# |    n_updates        | 167191   |
# ----------------------------------
# mean_reward : 210.88461508984375
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 290      |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1336     |
# |    fps              | 841      |
# |    time_elapsed     | 797      |
# |    total_timesteps  | 671166   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.27     |
# |    n_updates        | 167541   |
# ----------------------------------
# mean_reward : 208.75935931152344
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 292      |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1340     |
# |    fps              | 841      |
# |    time_elapsed     | 799      |
# |    total_timesteps  | 672330   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.312    |
# |    n_updates        | 167832   |
# ----------------------------------
# mean_reward : 214.8990115703125
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | 213      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1344     |
# |    fps              | 840      |
# |    time_elapsed     | 800      |
# |    total_timesteps  | 673476   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.162    |
# |    n_updates        | 168118   |
# ----------------------------------
# mean_reward : 228.6838479189453
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 296      |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1348     |
# |    fps              | 840      |
# |    time_elapsed     | 802      |
# |    total_timesteps  | 674523   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.299    |
# |    n_updates        | 168380   |
# ----------------------------------
# mean_reward : 223.57112591699217
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 293      |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1352     |
# |    fps              | 840      |
# |    time_elapsed     | 803      |
# |    total_timesteps  | 675527   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.232    |
# |    n_updates        | 168631   |
# ----------------------------------
# mean_reward : 225.81088132128906
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 297      |
# |    ep_rew_mean      | 222      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1356     |
# |    fps              | 840      |
# |    time_elapsed     | 804      |
# |    total_timesteps  | 676848   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.159    |
# |    n_updates        | 168961   |
# ----------------------------------
# mean_reward : 214.789828859375
# self.best_mean_reward: 260.6743967041016
# mean_reward : 219.3464059326172
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 300      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1360     |
# |    fps              | 840      |
# |    time_elapsed     | 806      |
# |    total_timesteps  | 678217   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.382    |
# |    n_updates        | 169304   |
# ----------------------------------
# mean_reward : 252.43717997753907
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 302      |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1364     |
# |    fps              | 840      |
# |    time_elapsed     | 808      |
# |    total_timesteps  | 679621   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.1      |
# |    n_updates        | 169655   |
# ----------------------------------
# mean_reward : 244.6305930908203
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 303      |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1368     |
# |    fps              | 840      |
# |    time_elapsed     | 809      |
# |    total_timesteps  | 680947   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.772    |
# |    n_updates        | 169986   |
# ----------------------------------
# mean_reward : 254.41777059277342
# self.best_mean_reward: 260.6743967041016
# mean_reward : 256.9595698037109
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 306      |
# |    ep_rew_mean      | 228      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1372     |
# |    fps              | 840      |
# |    time_elapsed     | 811      |
# |    total_timesteps  | 682316   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.304    |
# |    n_updates        | 170328   |
# ----------------------------------
# mean_reward : 256.759951421875
# self.best_mean_reward: 260.6743967041016
# mean_reward : 224.67875143457027
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 316      |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1376     |
# |    fps              | 840      |
# |    time_elapsed     | 814      |
# |    total_timesteps  | 684378   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.342    |
# |    n_updates        | 170844   |
# ----------------------------------
# mean_reward : 218.8406231279297
# self.best_mean_reward: 260.6743967041016
# mean_reward : 212.73282722070314
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 318      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1380     |
# |    fps              | 840      |
# |    time_elapsed     | 816      |
# |    total_timesteps  | 686156   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.132    |
# |    n_updates        | 171288   |
# ----------------------------------
# mean_reward : 195.93156308886722
# self.best_mean_reward: 260.6743967041016
# mean_reward : 217.45809423339847
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 334      |
# |    ep_rew_mean      | 224      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1384     |
# |    fps              | 840      |
# |    time_elapsed     | 819      |
# |    total_timesteps  | 688939   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.176    |
# |    n_updates        | 171984   |
# ----------------------------------
# mean_reward : 211.7573080605469
# self.best_mean_reward: 260.6743967041016
# mean_reward : 177.83766278613285
# self.best_mean_reward: 260.6743967041016
# mean_reward : 125.26239216210939
# self.best_mean_reward: 260.6743967041016
# mean_reward : 70.21298600195314
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 365      |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1388     |
# |    fps              | 840      |
# |    time_elapsed     | 824      |
# |    total_timesteps  | 692939   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.561    |
# |    n_updates        | 172984   |
# ----------------------------------
# mean_reward : 21.683612034179703
# self.best_mean_reward: 260.6743967041016
# mean_reward : 64.25209714062501
# self.best_mean_reward: 260.6743967041016
# mean_reward : 60.12986140234376
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 388      |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1392     |
# |    fps              | 840      |
# |    time_elapsed     | 828      |
# |    total_timesteps  | 696271   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.277    |
# |    n_updates        | 173817   |
# ----------------------------------
# mean_reward : 63.452007160156256
# self.best_mean_reward: 260.6743967041016
# mean_reward : 49.49429495703125
# self.best_mean_reward: 260.6743967041016
# mean_reward : 0.3872571582031199
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 396      |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1396     |
# |    fps              | 840      |
# |    time_elapsed     | 831      |
# |    total_timesteps  | 698446   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.214    |
# |    n_updates        | 174361   |
# ----------------------------------
# mean_reward : 53.12580000976562
# self.best_mean_reward: 260.6743967041016
# mean_reward : 73.81766234179686
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 414      |
# |    ep_rew_mean      | 196      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1400     |
# |    fps              | 840      |
# |    time_elapsed     | 834      |
# |    total_timesteps  | 701264   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.284    |
# |    n_updates        | 175065   |
# ----------------------------------
# mean_reward : 123.84572655468749
# self.best_mean_reward: 260.6743967041016
# mean_reward : 166.3551177421875
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 424      |
# |    ep_rew_mean      | 195      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1404     |
# |    fps              | 839      |
# |    time_elapsed     | 837      |
# |    total_timesteps  | 703452   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.29     |
# |    n_updates        | 175612   |
# ----------------------------------
# mean_reward : 130.37148288574218
# self.best_mean_reward: 260.6743967041016
# mean_reward : 158.37612918066407
# self.best_mean_reward: 260.6743967041016
# mean_reward : 176.3158014980469
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 434      |
# |    ep_rew_mean      | 191      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1408     |
# |    fps              | 839      |
# |    time_elapsed     | 840      |
# |    total_timesteps  | 706076   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.228    |
# |    n_updates        | 176268   |
# ----------------------------------
# mean_reward : 135.69481922949223
# self.best_mean_reward: 260.6743967041016
# mean_reward : 167.3905671357422
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 448      |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1412     |
# |    fps              | 839      |
# |    time_elapsed     | 843      |
# |    total_timesteps  | 708523   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.19     |
# |    n_updates        | 176880   |
# ----------------------------------
# mean_reward : 139.2374897324219
# self.best_mean_reward: 260.6743967041016
# mean_reward : 110.10415734570311
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 450      |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1416     |
# |    fps              | 839      |
# |    time_elapsed     | 845      |
# |    total_timesteps  | 709985   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.37     |
# |    n_updates        | 177246   |
# ----------------------------------
# mean_reward : 130.79750840625
# self.best_mean_reward: 260.6743967041016
# mean_reward : 134.06311597363276
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1420     |
# |    fps              | 839      |
# |    time_elapsed     | 848      |
# |    total_timesteps  | 712463   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.25     |
# |    n_updates        | 177865   |
# ----------------------------------
# mean_reward : 140.4281247705078
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 463      |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1424     |
# |    fps              | 839      |
# |    time_elapsed     | 849      |
# |    total_timesteps  | 713490   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.337    |
# |    n_updates        | 178122   |
# ----------------------------------
# mean_reward : 148.6155513378906
# self.best_mean_reward: 260.6743967041016
# mean_reward : 173.04929871386713
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 463      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1428     |
# |    fps              | 839      |
# |    time_elapsed     | 851      |
# |    total_timesteps  | 715102   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.452    |
# |    n_updates        | 178525   |
# ----------------------------------
# mean_reward : 167.94806354785152
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 465      |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1432     |
# |    fps              | 839      |
# |    time_elapsed     | 853      |
# |    total_timesteps  | 716244   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.11     |
# |    n_updates        | 178810   |
# ----------------------------------
# mean_reward : 189.12898588281246
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 462      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1436     |
# |    fps              | 839      |
# |    time_elapsed     | 854      |
# |    total_timesteps  | 717410   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.35     |
# |    n_updates        | 179102   |
# ----------------------------------
# mean_reward : 215.45643014843745
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1440     |
# |    fps              | 839      |
# |    time_elapsed     | 856      |
# |    total_timesteps  | 718731   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.123    |
# |    n_updates        | 179432   |
# ----------------------------------
# mean_reward : 196.39703803515624
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 461      |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1444     |
# |    fps              | 839      |
# |    time_elapsed     | 857      |
# |    total_timesteps  | 719611   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.122    |
# |    n_updates        | 179652   |
# ----------------------------------
# mean_reward : 212.42908625585935
# self.best_mean_reward: 260.6743967041016
# mean_reward : 205.3828929472656
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 172      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1448     |
# |    fps              | 839      |
# |    time_elapsed     | 858      |
# |    total_timesteps  | 720969   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.903    |
# |    n_updates        | 179992   |
# ----------------------------------
# mean_reward : 165.84140893164061
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 466      |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1452     |
# |    fps              | 839      |
# |    time_elapsed     | 860      |
# |    total_timesteps  | 722118   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.917    |
# |    n_updates        | 180279   |
# ----------------------------------
# mean_reward : 138.1770937207031
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 166      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1456     |
# |    fps              | 839      |
# |    time_elapsed     | 861      |
# |    total_timesteps  | 723256   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.804    |
# |    n_updates        | 180563   |
# ----------------------------------
# mean_reward : 141.40672591308592
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 464      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1460     |
# |    fps              | 839      |
# |    time_elapsed     | 863      |
# |    total_timesteps  | 724581   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.501    |
# |    n_updates        | 180895   |
# ----------------------------------
# mean_reward : 167.25003507421874
# self.best_mean_reward: 260.6743967041016
# mean_reward : 211.91039855664062
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 466      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1464     |
# |    fps              | 839      |
# |    time_elapsed     | 865      |
# |    total_timesteps  | 726173   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.245    |
# |    n_updates        | 181293   |
# ----------------------------------
# mean_reward : 252.04886088476565
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 470      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1468     |
# |    fps              | 839      |
# |    time_elapsed     | 867      |
# |    total_timesteps  | 727974   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.254    |
# |    n_updates        | 181743   |
# ----------------------------------
# mean_reward : 253.25813238085942
# self.best_mean_reward: 260.6743967041016
# mean_reward : 252.23008127539066
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 468      |
# |    ep_rew_mean      | 162      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1472     |
# |    fps              | 839      |
# |    time_elapsed     | 868      |
# |    total_timesteps  | 729112   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.188    |
# |    n_updates        | 182027   |
# ----------------------------------
# mean_reward : 228.78355993847657
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 460      |
# |    ep_rew_mean      | 165      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 1476     |
# |    fps              | 839      |
# |    time_elapsed     | 870      |
# |    total_timesteps  | 730413   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.183    |
# |    n_updates        | 182353   |
# ----------------------------------
# mean_reward : 227.4663557314453
# self.best_mean_reward: 260.6743967041016
# mean_reward : 229.72208953125
# self.best_mean_reward: 260.6743967041016
# ----------------------------------
# | rollout/            |          |
# ...
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.468    |
# |    n_updates        | 242292   |
# ----------------------------------
# mean_reward : 130.0015857685547
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 247      |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2208     |
# |    fps              | 832      |
# |    time_elapsed     | 1166     |
# |    total_timesteps  | 970975   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.175    |
# |    n_updates        | 242493   |
# ----------------------------------
# mean_reward : 129.35629344628907
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 252      |
# |    ep_rew_mean      | 182      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2212     |
# |    fps              | 832      |
# |    time_elapsed     | 1168     |
# |    total_timesteps  | 972399   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.316    |
# |    n_updates        | 242849   |
# ----------------------------------
# mean_reward : 123.58623616894533
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 246      |
# |    ep_rew_mean      | 183      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2216     |
# |    fps              | 832      |
# |    time_elapsed     | 1168     |
# |    total_timesteps  | 973040   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.715    |
# |    n_updates        | 243009   |
# ----------------------------------
# mean_reward : 148.25189280761722
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 248      |
# |    ep_rew_mean      | 182      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2220     |
# |    fps              | 832      |
# |    time_elapsed     | 1170     |
# |    total_timesteps  | 974389   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.6      |
# |    n_updates        | 243347   |
# ----------------------------------
# mean_reward : 171.29280575097658
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 247      |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2224     |
# |    fps              | 832      |
# |    time_elapsed     | 1171     |
# |    total_timesteps  | 975247   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.244    |
# |    n_updates        | 243561   |
# ----------------------------------
# mean_reward : 193.13175825390627
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 251      |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2228     |
# |    fps              | 832      |
# |    time_elapsed     | 1173     |
# |    total_timesteps  | 976601   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.146    |
# |    n_updates        | 243900   |
# ----------------------------------
# mean_reward : 214.21474153710938
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 247      |
# |    ep_rew_mean      | 173      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2232     |
# |    fps              | 832      |
# |    time_elapsed     | 1174     |
# |    total_timesteps  | 977251   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.24     |
# |    n_updates        | 244062   |
# ----------------------------------
# mean_reward : 194.5599862597656
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 244      |
# |    ep_rew_mean      | 176      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2236     |
# |    fps              | 832      |
# |    time_elapsed     | 1175     |
# |    total_timesteps  | 978276   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.155    |
# |    n_updates        | 244318   |
# ----------------------------------
# mean_reward : 177.04318480273437
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2240     |
# |    fps              | 832      |
# |    time_elapsed     | 1176     |
# |    total_timesteps  | 979100   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.178    |
# |    n_updates        | 244524   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 240      |
# |    ep_rew_mean      | 175      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2244     |
# |    fps              | 832      |
# |    time_elapsed     | 1177     |
# |    total_timesteps  | 979867   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 2.11     |
# |    n_updates        | 244716   |
# ----------------------------------
# mean_reward : 163.70908980273435
# self.best_mean_reward: 278.27880096777346
# mean_reward : 156.0599561796875
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 242      |
# |    ep_rew_mean      | 177      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2248     |
# |    fps              | 832      |
# |    time_elapsed     | 1178     |
# |    total_timesteps  | 981036   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.1      |
# |    n_updates        | 245008   |
# ----------------------------------
# mean_reward : 191.49667325781252
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 245      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2252     |
# |    fps              | 832      |
# |    time_elapsed     | 1180     |
# |    total_timesteps  | 982203   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.246    |
# |    n_updates        | 245300   |
# ----------------------------------
# mean_reward : 215.4010243154297
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 246      |
# |    ep_rew_mean      | 182      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2256     |
# |    fps              | 832      |
# |    time_elapsed     | 1181     |
# |    total_timesteps  | 983058   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.173    |
# |    n_updates        | 245514   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 244      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2260     |
# |    fps              | 832      |
# |    time_elapsed     | 1182     |
# |    total_timesteps  | 983712   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.242    |
# |    n_updates        | 245677   |
# ----------------------------------
# mean_reward : 216.84314436132814
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 238      |
# |    ep_rew_mean      | 178      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2264     |
# |    fps              | 832      |
# |    time_elapsed     | 1182     |
# |    total_timesteps  | 984376   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.321    |
# |    n_updates        | 245843   |
# ----------------------------------
# mean_reward : 203.8881446884766
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 238      |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2268     |
# |    fps              | 832      |
# |    time_elapsed     | 1184     |
# |    total_timesteps  | 985258   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.235    |
# |    n_updates        | 246064   |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 234      |
# |    ep_rew_mean      | 179      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2272     |
# |    fps              | 832      |
# |    time_elapsed     | 1184     |
# |    total_timesteps  | 985931   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.171    |
# |    n_updates        | 246232   |
# ----------------------------------
# mean_reward : 174.01867270214845
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 232      |
# |    ep_rew_mean      | 181      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2276     |
# |    fps              | 832      |
# |    time_elapsed     | 1186     |
# |    total_timesteps  | 987090   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.568    |
# |    n_updates        | 246522   |
# ----------------------------------
# mean_reward : 174.76926287207033
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 230      |
# |    ep_rew_mean      | 180      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2280     |
# |    fps              | 832      |
# |    time_elapsed     | 1187     |
# |    total_timesteps  | 988147   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.128    |
# |    n_updates        | 246786   |
# ----------------------------------
# mean_reward : 201.9453512392578
# self.best_mean_reward: 278.27880096777346
# mean_reward : 229.97927453027344
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 236      |
# |    ep_rew_mean      | 182      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2284     |
# |    fps              | 832      |
# |    time_elapsed     | 1189     |
# |    total_timesteps  | 989473   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.165    |
# |    n_updates        | 247118   |
# ----------------------------------
# mean_reward : 260.14087114257813
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 234      |
# |    ep_rew_mean      | 186      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2288     |
# |    fps              | 831      |
# |    time_elapsed     | 1190     |
# |    total_timesteps  | 990453   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.193    |
# |    n_updates        | 247363   |
# ----------------------------------
# mean_reward : 257.5011536943359
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 243      |
# |    ep_rew_mean      | 190      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2292     |
# |    fps              | 831      |
# |    time_elapsed     | 1192     |
# |    total_timesteps  | 992071   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.17     |
# |    n_updates        | 247767   |
# ----------------------------------
# mean_reward : 256.02445867578126
# self.best_mean_reward: 278.27880096777346
# mean_reward : 258.8578032558594
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 249      |
# |    ep_rew_mean      | 194      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2296     |
# |    fps              | 831      |
# |    time_elapsed     | 1193     |
# |    total_timesteps  | 993283   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.54     |
# |    n_updates        | 248070   |
# ----------------------------------
# mean_reward : 235.57660773828127
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 259      |
# |    ep_rew_mean      | 193      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2300     |
# |    fps              | 831      |
# |    time_elapsed     | 1196     |
# |    total_timesteps  | 995244   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.271    |
# |    n_updates        | 248560   |
# ----------------------------------
# mean_reward : 212.27077309667965
# self.best_mean_reward: 278.27880096777346
# mean_reward : 217.51193159375003
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 269      |
# |    ep_rew_mean      | 198      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2304     |
# |    fps              | 831      |
# |    time_elapsed     | 1198     |
# |    total_timesteps  | 997097   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.396    |
# |    n_updates        | 249024   |
# ----------------------------------
# mean_reward : 198.6826778408203
# self.best_mean_reward: 278.27880096777346
# mean_reward : 199.8986805810547
# self.best_mean_reward: 278.27880096777346
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 279      |
# |    ep_rew_mean      | 200      |
# |    exploration_rate | 0.02     |
# | time/               |          |
# |    episodes         | 2308     |
# |    fps              | 831      |
# |    time_elapsed     | 1200     |
# |    total_timesteps  | 998897   |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 1.67     |
# |    n_updates        | 249474   |
# ----------------------------------
# mean_reward : 213.4315779560547
# self.best_mean_reward: 278.27880096777346

# %% [markdown]
# ## Carga do Agente Treinado

# %%
del model
model = DQN.load("/content/best_model.zip")

# %% [markdown]
# ## Avaliação do Agente Treinado

# %%
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)

print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=187.15 +/- 54.30916434026357

# %% [markdown]
# ## Criar Vídeo do Agente Atuando

# %%
def convert_to_video(images, video_path):
  kargs = { 'macro_block_size': 1 }
  imageio.mimsave(video_path, [np.array(img) for i, img in enumerate(images)], fps=15, **kargs)

# %%
env = gym.make('LunarLander-v2', render_mode = "rgb_array")
obs = env.reset()
print(obs[0])
# Out:
# [-0.00752335  1.4029578  -0.7620645  -0.3539162   0.00872461  0.17261893
#   0.          0.        ]

# %%
images = []
obs = obs[0]
for i in range(1000):

    action, _state  = model.predict(obs, deterministic=True)

    obs, reward, done, truncated, info = env.step(action)

    img = env.render()
    images.append(img)

    if done:
      obs = env.reset()
      obs = obs[0]

# %%
video_path = "replay.mp4"
convert_to_video(images, video_path)

# %%
# Show video
mp4 = open(video_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML("""
<video width=400 controls>
      <source src="%s" type="video/mp4">
</video>
""" % data_url)
# Out:
# <video width=400 controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
